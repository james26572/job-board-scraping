# %%
# %pip install -U python-jobspy
# Out:
# Collecting python-jobspy
#   Downloading python_jobspy-1.1.51-py3-none-any.whl (29 kB)
# Collecting NUMPY==1.24.2
#   Downloading numpy-1.24.2-cp310-cp310-win_amd64.whl (14.8 MB)
# Collecting beautifulsoup4<5.0.0,>=4.12.2
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Collecting markdownify<0.12.0,>=0.11.6
#   Downloading markdownify-0.11.6-py3-none-any.whl (16 kB)
# Collecting pydantic<3.0.0,>=2.3.0
#   Downloading pydantic-2.6.4-py3-none-any.whl (394 kB)
# Collecting tls-client<2.0.0,>=1.0.1
#   Downloading tls_client-1.0.1-py3-none-any.whl (41.3 MB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from python-jobspy) (2.31.0)
# Collecting pandas<3.0.0,>=2.1.0
#   Downloading pandas-2.2.1-cp310-cp310-win_amd64.whl (11.6 MB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: six<2,>=1.15 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from markdownify<0.12.0,>=0.11.6->python-jobspy) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2.9.0)
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Collecting annotated-types>=0.4.0
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from pydantic<3.0.0,>=2.3.0->python-jobspy) (4.10.0)
# Collecting pydantic-core==2.16.3
#   Downloading pydantic_core-2.16.3-cp310-none-win_amd64.whl (1.9 MB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (3.6)
# Installing collected packages: soupsieve, tzdata, pytz, pydantic-core, NUMPY, beautifulsoup4, annotated-types, tls-client, pydantic, pandas, markdownify, python-jobspy
# Successfully installed NUMPY-1.24.2 annotated-types-0.6.0 beautifulsoup4-4.12.3 markdownify-0.11.6 pandas-2.2.1 pydantic-2.6.4 pydantic-core-2.16.3 python-jobspy-1.1.51 pytz-2024.1 soupsieve-2.5 tls-client-1.0.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\buckl\anaconda3\envs\pycharmproject\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import csv
from jobspy import scrape_jobs
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
job_titles = ['software engineer','financial analyst','accountant','investment banker','product manager',
              'data scientist','project manager','sales manager','marketing specialist','web developer']

# %%
results = pd.DataFrame({})

for job_title in job_titles:
    jobs = scrape_jobs(
    site_name=["linkedin"],
    search_term=job_title,
    location="London",
    results_wanted=100,
    hours_old=72, # (only Linkedin/Indeed is hour specific, others round up to days old)
    country_indeed='UK'  # only needed for indeed / glassdoor
)
    print(f"Found {len(jobs)} jobs")
    results = pd.concat([results,jobs],axis = 0)
# Out:
# 2024-03-15 17:22:21,662 - JobSpy - INFO - LinkedIn search page: 1
# 2024-03-15 17:22:28,287 - JobSpy - INFO - LinkedIn search page: 2
# 2024-03-15 17:22:34,251 - JobSpy - INFO - LinkedIn search page: 3
# 2024-03-15 17:22:41,304 - JobSpy - INFO - LinkedIn search page: 4
# 2024-03-15 17:22:49,420 - JobSpy - INFO - LinkedIn search page: 5
# 2024-03-15 17:22:54,413 - JobSpy - INFO - LinkedIn search page: 6
# 2024-03-15 17:22:56,405 - JobSpy - INFO - Linkedin finished scraping
# 2024-03-15 17:22:56,802 - JobSpy - INFO - LinkedIn search page: 1
# Found 100 jobs
# 2024-03-15 17:26:57,041 - JobSpy - INFO - Linkedin finished scraping
# 2024-03-15 17:26:57,408 - JobSpy - INFO - LinkedIn search page: 1
# Found 100 jobs
# 2024-03-15 17:27:03,440 - JobSpy - INFO - LinkedIn search page: 2
# 2024-03-15 17:27:10,023 - JobSpy - INFO - LinkedIn search page: 3
# 2024-03-15 17:27:19,660 - JobSpy - INFO - LinkedIn search page: 4
# 2024-03-15 17:27:25,607 - JobSpy - INFO - LinkedIn search page: 5
# 2024-03-15 17:27:33,814 - JobSpy - INFO - LinkedIn search page: 6
# 2024-03-15 17:27:41,386 - JobSpy - INFO - LinkedIn search page: 7
# 2024-03-15 17:27:42,772 - JobSpy - INFO - Linkedin finished scraping
# 2024-03-15 17:27:43,121 - JobSpy - INFO - LinkedIn search page: 1
# Found 100 jobs
# 2024-03-15 17:27:51,140 - JobSpy - INFO - LinkedIn search page: 2
# 2024-03-15 17:27:56,944 - JobSpy - INFO - LinkedIn search page: 3
# 2024-03-15 17:28:02,157 - JobSpy - INFO - LinkedIn search page: 4
# 2024-03-15 17:28:10,342 - JobSpy - INFO - LinkedIn search page: 5
# 2024-03-15 17:28:12,000 - JobSpy - INFO - Linkedin finished scraping
# 2024-03-15 17:28:12,479 - JobSpy - INFO - LinkedIn search page: 1
# Found 100 jobs
# 2024-03-15 17:28:18,733 - JobSpy - INFO - LinkedIn search page: 2
# 2024-03-15 17:28:26,042 - JobSpy - INFO - LinkedIn search page: 3
# 2024-03-15 17:28:33,401 - JobSpy - INFO - LinkedIn search page: 4
# 2024-03-15 17:28:39,961 - JobSpy - INFO - LinkedIn search page: 5
# 2024-03-15 17:28:46,542 - JobSpy - INFO - LinkedIn search page: 6
# 2024-03-15 17:28:51,192 - JobSpy - INFO - LinkedIn search page: 7
# 2024-03-15 17:28:58,873 - JobSpy - INFO - LinkedIn search page: 8
# 2024-03-15 17:29:00,079 - JobSpy - INFO - Linkedin finished scraping
# Found 89 jobs

# %%
results
# Out:
#         site                                        job_url job_url_direct  \
# 1   linkedin  https://www.linkedin.com/jobs/view/3856752104           None
# 5   linkedin  https://www.linkedin.com/jobs/view/3756226552           None
# 9   linkedin  https://www.linkedin.com/jobs/view/3855534376           None
# 17  linkedin  https://www.linkedin.com/jobs/view/3833952768           None
# 24  linkedin  https://www.linkedin.com/jobs/view/3842157932           None
# ..       ...                                            ...            ...
# 75  linkedin  https://www.linkedin.com/jobs/view/3856022823           None
# 76  linkedin  https://www.linkedin.com/jobs/view/3856635020           None
# 82  linkedin  https://www.linkedin.com/jobs/view/3856454106           None
# 87  linkedin  https://www.linkedin.com/jobs/view/3856628980           None
# 88  linkedin  https://www.linkedin.com/jobs/view/3854931352           None
#
#                                                 title  \
# 1                                   Software Engineer
# 5                                   Software Engineer
# 9                      Software Engineer, Google Play
# 17                                      Web Developer
# 24              JavaScript Engineer - TS, React, Node
# ..                                                ...
# 75                   Senior ServiceNow ITSM Developer
# 76                      Salesforce Vlocity Consultant
# 82  .NET Developer, .NET 8, C# - Global Internet I...
# 87                         Trainee Driving Instructor
# 88                                Commercial Director
#
#                                        company                     location  \
# 1                                Let's Do This          London, England, UK
# 5   Paragon Alpha - Hedge Fund Talent Business  Greater London, England, UK
# 9                                       Google          London, England, UK
# 17                                   The Profs  Greater London, England, UK
# 24                              Oliver Bernard  Greater London, England, UK
# ..                                         ...                          ...
# 75                                CareerAddict          London, England, UK
# 76                                ClickJobs.io          London, England, UK
# 82                                ClickJobs.io          London, England, UK
# 87                                ClickJobs.io     Basingstoke, England, UK
# 88                               Guardian Jobs          Harrow, England, UK
#
#    job_type date_posted interval  min_amount  ...  company_url_direct  \
# 1      None  2024-03-14     None         NaN  ...                None
# 5      None  2024-03-14     None         NaN  ...                None
# 9      None  2024-03-14     None         NaN  ...                None
# 17     None  2024-03-14     None     40000.0  ...                None
# 24     None  2024-03-14     None     60000.0  ...                None
# ..      ...         ...      ...         ...  ...                 ...
# 75     None         NaN     None         NaN  ...                None
# 76     None         NaN     None         NaN  ...                None
# 82     None         NaN     None         NaN  ...                None
# 87     None         NaN     None         NaN  ...                None
# 88     None         NaN     None         NaN  ...                None
#
#    company_addresses company_industry company_num_employees company_revenue  \
# 1               None             None                  None            None
# 5               None             None                  None            None
# 9               None             None                  None            None
# 17              None             None                  None            None
# 24              None             None                  None            None
# ..               ...              ...                   ...             ...
# 75              None             None                  None            None
# 76              None             None                  None            None
# 82              None             None                  None            None
# 87              None             None                  None            None
# 88              None             None                  None            None
#
#    company_description logo_photo_url banner_photo_url ceo_name ceo_photo_url
# 1                 None           None             None     None          None
# 5                 None           None             None     None          None
# 9                 None           None             None     None          None
# 17                None           None             None     None          None
# 24                None           None             None     None          None
# ..                 ...            ...              ...      ...           ...
# 75                None           None             None     None          None
# 76                None           None             None     None          None
# 82                None           None             None     None          None
# 87                None           None             None     None          None
# 88                None           None             None     None          None
#
# [894 rows x 26 columns]

# %%
def get_job_description(description_url):
    response = requests.get(description_url)
    soup = BeautifulSoup(response.content,'html.parser')
    description = soup.find('section',class_ = 'show-more-less-html')
    if description is None:
        return None
    cleaned_description = description.text.strip()
    return cleaned_description

# %%
def fetch_descriptions(urls, max_workers=10):
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_url = {executor.submit(get_job_description, url): url for url in urls}
        results = []
        for future in as_completed(future_to_url):
            url = future_to_url[future]
            try:
                result = future.result()
                results.append(result)
            except Exception as e:
                print(f"Error fetching job description from {url}: {e}")
                results.append(None)
    return results

# %%
results['description'] = fetch_descriptions(results.job_url)

# %%
results.drop(columns=['interval', 'min_amount', 'max_amount',
       'currency', 'is_remote', 'emails','company_url',
       'company_url_direct', 'company_addresses', 'company_industry',
       'company_num_employees', 'company_revenue', 'company_description',
       'logo_photo_url', 'banner_photo_url', 'ceo_name', 'ceo_photo_url',], inplace = True)

# %%
results.to_csv('jobs.csv', index=False)
